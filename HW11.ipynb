# %%
import tensorflow as tf
from tensorflow.python.training.moving_averages import assign_moving_average
import numpy as np
import os
import cv2
import numpy as np
import random as rn
import tensorflow as tf
import threading
import time

global n_classes
n_classes = 50

# %%
tf.reset_default_graph()
_weights = {
        'wc1': tf.get_variable("wc1", [7, 7, 3, 96], initializer=tf.glorot_uniform_initializer()),
        'wc2': tf.get_variable('wc2',[5, 5, 96, 256], initializer=tf.glorot_uniform_initializer()),
        'wc3': tf.get_variable('wc3',[3, 3, 256, 384], initializer=tf.glorot_uniform_initializer()),
        'wc4': tf.get_variable('wc4',[3, 3, 384, 384], initializer=tf.glorot_uniform_initializer()),
        'wc5': tf.get_variable('wc5',[3, 3, 384, 256], initializer=tf.glorot_uniform_initializer()),
        'wd2': tf.get_variable('wd2',[4096, 4096], initializer=tf.glorot_uniform_initializer()),
        'out': tf.get_variable('out',[4096, n_classes], initializer=tf.glorot_uniform_initializer())
    }
_biases = {
        'bc1': tf.get_variable('bc1',[96], initializer=tf.glorot_uniform_initializer()),
        'bc2': tf.get_variable('bc2',[256], initializer=tf.glorot_uniform_initializer()),
        'bc3': tf.get_variable('bc3',[384], initializer=tf.glorot_uniform_initializer()),
        'bc4': tf.get_variable('bc4',[384], initializer=tf.glorot_uniform_initializer()),
        'bc5': tf.get_variable('bc5',[256], initializer=tf.glorot_uniform_initializer()),
        'bd2': tf.get_variable('db2',[4096], initializer=tf.glorot_uniform_initializer()),
        'out': tf.get_variable('bout',[n_classes], initializer=tf.glorot_uniform_initializer())
    }

# %%
def activation(x,name="activation"):
    return tf.nn.relu(x, name=name)
    
def conv2d(name, l_input, w, b, s, p, scope):
    l_input = tf.nn.conv2d(l_input, w, strides=[1,s,s,1], padding=p, name=name)
    l_input = activation(l_input+b)
    
    return l_input

def max_pool(name, l_input, k, s):
    return tf.nn.max_pool(l_input, ksize=[1, k, k, 1], strides=[1, s, s, 1], padding='VALID', name=name)

def norm(l_input, lsize=4, name="lrn"):
    return tf.nn.lrn(l_input, lsize, bias=1.0, alpha=0.001 / 9.0, beta=0.75, name=name)

# %%
   
def alex_net(_X, _dropout, batch_size):
    conv1 = conv2d('conv1', _X, _weights['wc1'], _biases['bc1'], 3, 'VALID', 'conv1')
    pool1 = max_pool('pool1', conv1, k=3,s=2)
    conv2 = conv2d('conv2', pool1, _weights['wc2'], _biases['bc2'], 1, 'SAME', 'conv2')
    pool2 = max_pool('pool2', conv2, k=3,s=2)
    conv3 = conv2d('conv3', pool2, _weights['wc3'], _biases['bc3'], 1, 'SAME', 'conv3')
    conv4 = conv2d('conv4', conv3, _weights['wc4'], _biases['bc4'], 1, 'SAME', 'conv4')
    conv5 = conv2d('conv5', conv4, _weights['wc5'], _biases['bc5'], 1, 'SAME', 'conv5')
    pool5 = max_pool('pool2', conv5, k=3,s=2)
    # Find current size of conv5 to fit the requirement of FC1.
    sizes = pool5.get_shape().as_list()
    neurons =  sizes[1]*sizes[2]*sizes[3]
    dense1 = tf.reshape(pool5, [batch_size, neurons]) # Reshape conv5 output to fit dense layer input
    wei_den1 = tf.get_variable('wd3',[neurons, 4096], initializer=tf.glorot_uniform_initializer())
    b_den1 =  tf.get_variable('wd4',[4096], initializer=tf.glorot_uniform_initializer())
    
    dense1 = activation(tf.matmul(dense1, wei_den1) + b_den1, name='fc1') # Relu activation
    dd1=tf.nn.dropout(dense1, _dropout)
    dense2 = activation(tf.matmul(dd1, _weights['wd2']) + _biases['bd2'], name='fc2') # Relu activation
    out = tf.matmul(dense2, _weights['out']) + _biases['out'] # Relu activation

    return out

# %%
#==========================================================================
#=============Reading data in multithreading manner========================
#==========================================================================
def read_labeled_image_list(image_list_file, training_img_dir):
    """Reads a .txt file containing pathes and labeles
    Args:
       image_list_file: a .txt file with one /path/to/image per line
       label: optionally, if set label will be pasted after each line
    Returns:
       List with all filenames in file image_list_file
    """
    f = open(image_list_file, 'r')
    filenames = []
    labels = []

    for line in f:
        filename, label = line[:-1].split(' ')
        filename = training_img_dir+filename
        filenames.append(filename)
        labels.append(int(label))
        
    return filenames, labels
    
    
def read_images_from_disk(input_queue, size1=256):
    """Consumes a single filename and label as a ' '-delimited string.
    Args:
      filename_and_label_tensor: A scalar string tensor.
    Returns:
      Two tensors: the decoded image, and the string label.
    """
    label = input_queue[1]
    fn=input_queue[0]
    file_contents = tf.read_file(input_queue[0])
    example = tf.image.decode_jpeg(file_contents, channels=3)
    
    #example = tf.image.decode_png(file_contents, channels=3, name="dataset_image") # png fo rlfw
    example=tf.image.resize_images(example, [size1,size1])
    return example, label, fn
    
def setup_inputs(sess, filenames, training_img_dir, image_size=256, crop_size=224, isTest=False, batch_size=128):
    
    # Read each image file
    image_list, label_list = read_labeled_image_list(filenames, training_img_dir)

    images = tf.cast(image_list, tf.string)
    labels = tf.cast(label_list, tf.int64)
     # Makes an input queue
    if isTest is False:
        isShuffle = True
    else:
        isShuffle = False
        
    input_queue = tf.train.slice_input_producer([images, labels], shuffle=isShuffle)
    image, y,fn = read_images_from_disk(input_queue)

    channels = 3
    image.set_shape([None, None, channels])
        
    # Crop and other random augmentations
    if isTest is False:
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_saturation(image, .95, 1.05)
        image = tf.image.random_brightness(image, .05)
        image = tf.image.random_contrast(image, .95, 1.05)
        

    image = tf.random_crop(image, [crop_size, crop_size, 3])
    image = tf.cast(image, tf.float32)/255.0
    
    image, y,fn = tf.train.batch([image, y, fn], batch_size=batch_size, capacity=4,name='labels_and_images')

    tf.train.start_queue_runners(sess=sess)

    return image, y, fn, len(label_list)

# %%
# Training setting
batch_size = 128 
display_step = 80
dropout = 0.5# Dropout rate

# %%
keep_prob = tf.placeholder(tf.float32)          # Dropout rate to be fed
learning_rate = tf.placeholder(tf.float32)      # Learning rate to be fed
lr = 1e-3                                   # Learning rate start

# Setup the tensorflow...
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

print("Preparing the training & validation data...")
train_data, train_labels, filelist1, glen1 = setup_inputs(sess, "train.txt", "./", batch_size=batch_size)
val_data, val_labels, filelist2, tlen1 = setup_inputs(sess, "val.txt", "./", batch_size=batch_size)

max_iter = glen1*100

print("Preparing the training model with learning rate = %.5f..." % (lr))

with tf.variable_scope("alexnet", reuse=tf.AUTO_REUSE) as scope:
    pred = alex_net(train_data,keep_prob,batch_size)

with tf.name_scope('Loss_and_Accuracy'):
  cost = tf.losses.sparse_softmax_cross_entropy(labels=train_labels, logits=pred)
  optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)
  correct_prediction = tf.equal(tf.argmax(pred, 1), train_labels)
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
  top5=tf.reduce_mean(tf.cast(tf.nn.in_top_k(pred, train_labels, 5), tf.float32))
  
  tf.summary.scalar('Loss', cost)
  tf.summary.scalar('Training_Accuracy', accuracy)
  tf.summary.scalar('Top-5_accuracy', top5)
# Out:
# Preparing the training & validation data...
# W0710 08:10:45.846871 140275526670208 deprecation.py:323] From <ipython-input-39-b45acdff6d74>:51: slice_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(tuple(tensor_list)).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0710 08:10:45.860845 140275526670208 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:374: range_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.range(limit).shuffle(limit).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0710 08:10:45.917646 140275526670208 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:320: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# W0710 08:10:45.923182 140275526670208 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:190: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# W0710 08:10:45.929902 140275526670208 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:199: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0710 08:10:45.934697 140275526670208 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:199: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# W0710 08:10:46.011207 140275526670208 deprecation.py:323] From <ipython-input-39-b45acdff6d74>:68: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# W0710 08:10:46.024944 140275526670208 deprecation.py:323] From <ipython-input-39-b45acdff6d74>:70: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# Preparing the training model with learning rate = 0.00100...
# W0710 08:10:46.696639 140275526670208 deprecation.py:506] From <ipython-input-38-5f240c5a2da9>:19: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0710 08:10:46.733398 140275526670208 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/losses/losses_impl.py:121: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
saver = tf.train.Saver()
init = tf.global_variables_initializer()
sess.run(init)
step = 0
writer = tf.summary.FileWriter("/tmp/log2", sess.graph)
summaries = tf.summary.merge_all()

print("We are going to train the ImageNet model based on AlexNet!!!")
while (step * batch_size) < max_iter:
    epoch1=np.floor((step*batch_size)/glen1)
    if (((step*batch_size)%glen1 < batch_size) & (lr==1e-3) & (epoch1 >2)):
        lr /= 10

    sess.run(optimizer,  feed_dict={keep_prob: dropout, learning_rate: lr})

    if (step % 15000==1) & (step>15000):
        save_path = saver.save(sess, "checkpoint/tf_alex_model_iter" + str(step) + ".ckpt")
        print("Model saved in file at iteration %d: %s" % (step*batch_size,save_path))

    if step % display_step == 1:
        # calculate the loss
        loss, acc, top5acc, summaries_string = sess.run([cost, accuracy, top5, summaries], feed_dict={keep_prob: 1.})
        print("Iter=%d/epoch=%d, Loss=%.6f, Training Accuracy=%.6f, Top-5 Accuracy=%.6f, lr=%f" % (step*batch_size, epoch1 ,loss, acc, top5acc, lr))
        writer.add_summary(summaries_string, step)


    step += 1
print("Optimization Finished!")
save_path = saver.save(sess, "checkpoint/tf_alex_model.ckpt")
print("Model saved in file: %s" % save_path)
# Out:
# We are going to train the ImageNet model based on AlexNet!!!
# Iter=128/epoch=0, Loss=4.159305, Training Accuracy=0.000000, Top-5 Accuracy=0.093750, lr=0.001000
# Iter=10368/epoch=0, Loss=3.813807, Training Accuracy=0.062500, Top-5 Accuracy=0.156250, lr=0.001000
# Iter=20608/epoch=0, Loss=3.673462, Training Accuracy=0.101562, Top-5 Accuracy=0.273438, lr=0.001000
# Iter=30848/epoch=0, Loss=3.725368, Training Accuracy=0.078125, Top-5 Accuracy=0.195312, lr=0.001000
# Iter=41088/epoch=0, Loss=3.727109, Training Accuracy=0.023438, Top-5 Accuracy=0.179688, lr=0.001000
# Iter=51328/epoch=0, Loss=3.591070, Training Accuracy=0.070312, Top-5 Accuracy=0.250000, lr=0.001000
# Iter=61568/epoch=0, Loss=3.518040, Training Accuracy=0.148438, Top-5 Accuracy=0.343750, lr=0.001000
# Iter=71808/epoch=1, Loss=3.549055, Training Accuracy=0.062500, Top-5 Accuracy=0.296875, lr=0.001000
# Iter=82048/epoch=1, Loss=3.259313, Training Accuracy=0.101562, Top-5 Accuracy=0.421875, lr=0.001000
# Iter=92288/epoch=1, Loss=3.167912, Training Accuracy=0.164062, Top-5 Accuracy=0.445312, lr=0.001000
# Iter=102528/epoch=1, Loss=3.336766, Training Accuracy=0.117188, Top-5 Accuracy=0.375000, lr=0.001000
# Iter=112768/epoch=1, Loss=3.229095, Training Accuracy=0.164062, Top-5 Accuracy=0.453125, lr=0.001000
# Iter=123008/epoch=1, Loss=3.186670, Training Accuracy=0.140625, Top-5 Accuracy=0.421875, lr=0.001000
# Iter=133248/epoch=2, Loss=3.016325, Training Accuracy=0.171875, Top-5 Accuracy=0.507812, lr=0.001000
# Iter=143488/epoch=2, Loss=2.961549, Training Accuracy=0.250000, Top-5 Accuracy=0.570312, lr=0.001000
# Iter=153728/epoch=2, Loss=3.090840, Training Accuracy=0.203125, Top-5 Accuracy=0.492188, lr=0.001000
# Iter=163968/epoch=2, Loss=2.988574, Training Accuracy=0.171875, Top-5 Accuracy=0.515625, lr=0.001000
# Iter=174208/epoch=2, Loss=2.708048, Training Accuracy=0.210938, Top-5 Accuracy=0.570312, lr=0.001000
# Iter=184448/epoch=2, Loss=2.972905, Training Accuracy=0.179688, Top-5 Accuracy=0.468750, lr=0.001000
# Iter=194688/epoch=3, Loss=2.797201, Training Accuracy=0.226562, Top-5 Accuracy=0.554688, lr=0.000100
# Iter=204928/epoch=3, Loss=2.727985, Training Accuracy=0.250000, Top-5 Accuracy=0.593750, lr=0.000100
# Iter=215168/epoch=3, Loss=2.559938, Training Accuracy=0.289062, Top-5 Accuracy=0.640625, lr=0.000100
# Iter=225408/epoch=3, Loss=2.713495, Training Accuracy=0.250000, Top-5 Accuracy=0.671875, lr=0.000100
# Iter=235648/epoch=3, Loss=2.760511, Training Accuracy=0.242188, Top-5 Accuracy=0.640625, lr=0.000100
# Iter=245888/epoch=3, Loss=2.575464, Training Accuracy=0.296875, Top-5 Accuracy=0.601562, lr=0.000100
# Iter=256128/epoch=4, Loss=2.687626, Training Accuracy=0.210938, Top-5 Accuracy=0.578125, lr=0.000100
# Iter=266368/epoch=4, Loss=2.550421, Training Accuracy=0.320312, Top-5 Accuracy=0.656250, lr=0.000100
# Iter=276608/epoch=4, Loss=2.679485, Training Accuracy=0.210938, Top-5 Accuracy=0.617188, lr=0.000100
# Iter=286848/epoch=4, Loss=2.555668, Training Accuracy=0.289062, Top-5 Accuracy=0.679688, lr=0.000100
# Iter=297088/epoch=4, Loss=2.452882, Training Accuracy=0.312500, Top-5 Accuracy=0.656250, lr=0.000100
# Iter=307328/epoch=4, Loss=2.568042, Training Accuracy=0.265625, Top-5 Accuracy=0.640625, lr=0.000100
# Iter=317568/epoch=5, Loss=2.513715, Training Accuracy=0.273438, Top-5 Accuracy=0.593750, lr=0.000100
# Iter=327808/epoch=5, Loss=2.407408, Training Accuracy=0.312500, Top-5 Accuracy=0.726562, lr=0.000100
# Iter=338048/epoch=5, Loss=2.309364, Training Accuracy=0.343750, Top-5 Accuracy=0.703125, lr=0.000100
# Iter=348288/epoch=5, Loss=2.393073, Training Accuracy=0.296875, Top-5 Accuracy=0.664062, lr=0.000100
# Iter=358528/epoch=5, Loss=2.298470, Training Accuracy=0.343750, Top-5 Accuracy=0.703125, lr=0.000100
# Iter=368768/epoch=5, Loss=2.662264, Training Accuracy=0.273438, Top-5 Accuracy=0.625000, lr=0.000100
# Iter=379008/epoch=5, Loss=2.495427, Training Accuracy=0.273438, Top-5 Accuracy=0.687500, lr=0.000100
# Iter=389248/epoch=6, Loss=2.667309, Training Accuracy=0.250000, Top-5 Accuracy=0.656250, lr=0.000100
# Iter=399488/epoch=6, Loss=2.316006, Training Accuracy=0.375000, Top-5 Accuracy=0.742188, lr=0.000100
# Iter=409728/epoch=6, Loss=2.426472, Training Accuracy=0.320312, Top-5 Accuracy=0.703125, lr=0.000100
# Iter=419968/epoch=6, Loss=2.384270, Training Accuracy=0.242188, Top-5 Accuracy=0.695312, lr=0.000100
# Iter=430208/epoch=6, Loss=2.213812, Training Accuracy=0.359375, Top-5 Accuracy=0.757812, lr=0.000100
# Iter=440448/epoch=6, Loss=2.405664, Training Accuracy=0.343750, Top-5 Accuracy=0.687500, lr=0.000100
# Iter=450688/epoch=7, Loss=2.215344, Training Accuracy=0.343750, Top-5 Accuracy=0.695312, lr=0.000100
# Iter=460928/epoch=7, Loss=2.147277, Training Accuracy=0.375000, Top-5 Accuracy=0.750000, lr=0.000100
# Iter=471168/epoch=7, Loss=2.110764, Training Accuracy=0.414062, Top-5 Accuracy=0.750000, lr=0.000100
# Iter=481408/epoch=7, Loss=2.268190, Training Accuracy=0.320312, Top-5 Accuracy=0.687500, lr=0.000100
# Iter=491648/epoch=7, Loss=2.492604, Training Accuracy=0.296875, Top-5 Accuracy=0.687500, lr=0.000100
# Iter=501888/epoch=7, Loss=2.458975, Training Accuracy=0.328125, Top-5 Accuracy=0.664062, lr=0.000100
# Iter=512128/epoch=8, Loss=2.464988, Training Accuracy=0.328125, Top-5 Accuracy=0.664062, lr=0.000100
# Iter=522368/epoch=8, Loss=2.066923, Training Accuracy=0.375000, Top-5 Accuracy=0.757812, lr=0.000100
# Iter=532608/epoch=8, Loss=2.348612, Training Accuracy=0.343750, Top-5 Accuracy=0.703125, lr=0.000100
# Iter=542848/epoch=8, Loss=2.267354, Training Accuracy=0.351562, Top-5 Accuracy=0.710938, lr=0.000100
# Iter=553088/epoch=8, Loss=2.281344, Training Accuracy=0.351562, Top-5 Accuracy=0.710938, lr=0.000100
# Iter=563328/epoch=8, Loss=2.307665, Training Accuracy=0.375000, Top-5 Accuracy=0.710938, lr=0.000100
# Iter=573568/epoch=9, Loss=1.996304, Training Accuracy=0.421875, Top-5 Accuracy=0.734375, lr=0.000100
# Iter=583808/epoch=9, Loss=2.219377, Training Accuracy=0.375000, Top-5 Accuracy=0.734375, lr=0.000100
# Iter=594048/epoch=9, Loss=2.158511, Training Accuracy=0.382812, Top-5 Accuracy=0.750000, lr=0.000100
# Iter=604288/epoch=9, Loss=2.230098, Training Accuracy=0.375000, Top-5 Accuracy=0.703125, lr=0.000100
# Iter=614528/epoch=9, Loss=2.301038, Training Accuracy=0.359375, Top-5 Accuracy=0.726562, lr=0.000100
# Iter=624768/epoch=9, Loss=2.129508, Training Accuracy=0.414062, Top-5 Accuracy=0.773438, lr=0.000100
# Iter=635008/epoch=10, Loss=2.061739, Training Accuracy=0.460938, Top-5 Accuracy=0.734375, lr=0.000100
# Iter=645248/epoch=10, Loss=2.021297, Training Accuracy=0.398438, Top-5 Accuracy=0.765625, lr=0.000100
# Iter=655488/epoch=10, Loss=2.121440, Training Accuracy=0.351562, Top-5 Accuracy=0.726562, lr=0.000100
# Iter=665728/epoch=10, Loss=1.927970, Training Accuracy=0.460938, Top-5 Accuracy=0.828125, lr=0.000100
# Iter=675968/epoch=10, Loss=2.190620, Training Accuracy=0.445312, Top-5 Accuracy=0.734375, lr=0.000100
# Iter=686208/epoch=10, Loss=2.026996, Training Accuracy=0.390625, Top-5 Accuracy=0.781250, lr=0.000100
# Iter=696448/epoch=10, Loss=2.054553, Training Accuracy=0.453125, Top-5 Accuracy=0.734375, lr=0.000100
# Iter=706688/epoch=11, Loss=2.174407, Training Accuracy=0.421875, Top-5 Accuracy=0.718750, lr=0.000100
# Iter=716928/epoch=11, Loss=2.100270, Training Accuracy=0.390625, Top-5 Accuracy=0.734375, lr=0.000100
# Iter=727168/epoch=11, Loss=1.983359, Training Accuracy=0.421875, Top-5 Accuracy=0.734375, lr=0.000100
# Iter=737408/epoch=11, Loss=1.918372, Training Accuracy=0.484375, Top-5 Accuracy=0.812500, lr=0.000100
# Iter=747648/epoch=11, Loss=1.713318, Training Accuracy=0.460938, Top-5 Accuracy=0.835938, lr=0.000100
# Iter=757888/epoch=11, Loss=2.024311, Training Accuracy=0.421875, Top-5 Accuracy=0.773438, lr=0.000100
# Iter=768128/epoch=12, Loss=1.939256, Training Accuracy=0.406250, Top-5 Accuracy=0.773438, lr=0.000100
# Iter=778368/epoch=12, Loss=1.890072, Training Accuracy=0.460938, Top-5 Accuracy=0.804688, lr=0.000100
# Iter=788608/epoch=12, Loss=1.977185, Training Accuracy=0.406250, Top-5 Accuracy=0.765625, lr=0.000100
# Iter=798848/epoch=12, Loss=2.161638, Training Accuracy=0.382812, Top-5 Accuracy=0.750000, lr=0.000100
# Iter=809088/epoch=12, Loss=1.918989, Training Accuracy=0.492188, Top-5 Accuracy=0.820312, lr=0.000100
# Iter=819328/epoch=12, Loss=1.715226, Training Accuracy=0.523438, Top-5 Accuracy=0.820312, lr=0.000100
# Iter=829568/epoch=13, Loss=1.837424, Training Accuracy=0.437500, Top-5 Accuracy=0.812500, lr=0.000100
# Iter=839808/epoch=13, Loss=1.942459, Training Accuracy=0.406250, Top-5 Accuracy=0.750000, lr=0.000100
# Iter=850048/epoch=13, Loss=1.830459, Training Accuracy=0.507812, Top-5 Accuracy=0.835938, lr=0.000100
# Iter=860288/epoch=13, Loss=1.942514, Training Accuracy=0.390625, Top-5 Accuracy=0.820312, lr=0.000100
# Iter=870528/epoch=13, Loss=2.064929, Training Accuracy=0.390625, Top-5 Accuracy=0.750000, lr=0.000100
# Iter=880768/epoch=13, Loss=1.857451, Training Accuracy=0.429688, Top-5 Accuracy=0.773438, lr=0.000100
# Iter=891008/epoch=14, Loss=1.902349, Training Accuracy=0.414062, Top-5 Accuracy=0.812500, lr=0.000100
# Iter=901248/epoch=14, Loss=1.587951, Training Accuracy=0.570312, Top-5 Accuracy=0.882812, lr=0.000100
# Iter=911488/epoch=14, Loss=1.718418, Training Accuracy=0.484375, Top-5 Accuracy=0.851562, lr=0.000100
# Iter=921728/epoch=14, Loss=1.773911, Training Accuracy=0.476562, Top-5 Accuracy=0.820312, lr=0.000100
# Iter=931968/epoch=14, Loss=1.816468, Training Accuracy=0.476562, Top-5 Accuracy=0.812500, lr=0.000100
# Iter=942208/epoch=14, Loss=1.823455, Training Accuracy=0.390625, Top-5 Accuracy=0.875000, lr=0.000100
# Iter=952448/epoch=15, Loss=1.518085, Training Accuracy=0.601562, Top-5 Accuracy=0.828125, lr=0.000100
# Iter=962688/epoch=15, Loss=1.896111, Training Accuracy=0.445312, Top-5 Accuracy=0.765625, lr=0.000100
# Iter=972928/epoch=15, Loss=1.873049, Training Accuracy=0.492188, Top-5 Accuracy=0.804688, lr=0.000100
# Iter=983168/epoch=15, Loss=1.563802, Training Accuracy=0.570312, Top-5 Accuracy=0.843750, lr=0.000100
# Iter=993408/epoch=15, Loss=1.738352, Training Accuracy=0.390625, Top-5 Accuracy=0.812500, lr=0.000100
# Iter=1003648/epoch=15, Loss=1.502364, Training Accuracy=0.593750, Top-5 Accuracy=0.859375, lr=0.000100
# Iter=1013888/epoch=16, Loss=1.808752, Training Accuracy=0.468750, Top-5 Accuracy=0.796875, lr=0.000100
# Iter=1024128/epoch=16, Loss=1.676195, Training Accuracy=0.507812, Top-5 Accuracy=0.859375, lr=0.000100
# Iter=1034368/epoch=16, Loss=1.826039, Training Accuracy=0.460938, Top-5 Accuracy=0.812500, lr=0.000100
# Iter=1044608/epoch=16, Loss=1.782342, Training Accuracy=0.445312, Top-5 Accuracy=0.851562, lr=0.000100
# Iter=1054848/epoch=16, Loss=1.440715, Training Accuracy=0.640625, Top-5 Accuracy=0.882812, lr=0.000100
# Iter=1065088/epoch=16, Loss=1.509060, Training Accuracy=0.601562, Top-5 Accuracy=0.859375, lr=0.000100
# Iter=1075328/epoch=16, Loss=1.692209, Training Accuracy=0.539062, Top-5 Accuracy=0.812500, lr=0.000100
# Iter=1085568/epoch=17, Loss=1.709040, Training Accuracy=0.523438, Top-5 Accuracy=0.828125, lr=0.000100
# Iter=1095808/epoch=17, Loss=1.355009, Training Accuracy=0.539062, Top-5 Accuracy=0.875000, lr=0.000100
# Iter=1106048/epoch=17, Loss=1.626299, Training Accuracy=0.539062, Top-5 Accuracy=0.875000, lr=0.000100
# Iter=1116288/epoch=17, Loss=1.826006, Training Accuracy=0.507812, Top-5 Accuracy=0.835938, lr=0.000100
# Iter=1126528/epoch=17, Loss=1.575233, Training Accuracy=0.539062, Top-5 Accuracy=0.820312, lr=0.000100
# Iter=1136768/epoch=17, Loss=1.541924, Training Accuracy=0.570312, Top-5 Accuracy=0.867188, lr=0.000100
# Iter=1147008/epoch=18, Loss=1.596171, Training Accuracy=0.562500, Top-5 Accuracy=0.843750, lr=0.000100
# Iter=1157248/epoch=18, Loss=1.399120, Training Accuracy=0.609375, Top-5 Accuracy=0.875000, lr=0.000100
# Iter=1167488/epoch=18, Loss=1.658432, Training Accuracy=0.539062, Top-5 Accuracy=0.820312, lr=0.000100
# Iter=1177728/epoch=18, Loss=1.450114, Training Accuracy=0.570312, Top-5 Accuracy=0.875000, lr=0.000100
# Iter=1187968/epoch=18, Loss=1.607975, Training Accuracy=0.531250, Top-5 Accuracy=0.828125, lr=0.000100
# Iter=1198208/epoch=18, Loss=1.529832, Training Accuracy=0.570312, Top-5 Accuracy=0.859375, lr=0.000100
# Iter=1208448/epoch=19, Loss=1.501017, Training Accuracy=0.562500, Top-5 Accuracy=0.859375, lr=0.000100
# Iter=1218688/epoch=19, Loss=1.414033, Training Accuracy=0.570312, Top-5 Accuracy=0.890625, lr=0.000100
# Iter=1228928/epoch=19, Loss=1.488956, Training Accuracy=0.554688, Top-5 Accuracy=0.867188, lr=0.000100
# Iter=1239168/epoch=19, Loss=1.656743, Training Accuracy=0.531250, Top-5 Accuracy=0.820312, lr=0.000100
# Iter=1249408/epoch=19, Loss=1.547379, Training Accuracy=0.578125, Top-5 Accuracy=0.859375, lr=0.000100
# Iter=1259648/epoch=19, Loss=1.385233, Training Accuracy=0.578125, Top-5 Accuracy=0.906250, lr=0.000100
# Iter=1269888/epoch=20, Loss=1.465169, Training Accuracy=0.562500, Top-5 Accuracy=0.890625, lr=0.000100
# Iter=1280128/epoch=20, Loss=1.313743, Training Accuracy=0.593750, Top-5 Accuracy=0.898438, lr=0.000100
# Iter=1290368/epoch=20, Loss=1.459313, Training Accuracy=0.570312, Top-5 Accuracy=0.851562, lr=0.000100
# Iter=1300608/epoch=20, Loss=1.353894, Training Accuracy=0.593750, Top-5 Accuracy=0.898438, lr=0.000100
# Iter=1310848/epoch=20, Loss=1.604787, Training Accuracy=0.492188, Top-5 Accuracy=0.820312, lr=0.000100
# Iter=1321088/epoch=20, Loss=1.315279, Training Accuracy=0.562500, Top-5 Accuracy=0.882812, lr=0.000100
# Iter=1331328/epoch=21, Loss=1.413497, Training Accuracy=0.578125, Top-5 Accuracy=0.843750, lr=0.000100
# Iter=1341568/epoch=21, Loss=1.441852, Training Accuracy=0.585938, Top-5 Accuracy=0.867188, lr=0.000100
# Iter=1351808/epoch=21, Loss=1.092613, Training Accuracy=0.742188, Top-5 Accuracy=0.953125, lr=0.000100
# Iter=1362048/epoch=21, Loss=1.328066, Training Accuracy=0.578125, Top-5 Accuracy=0.929688, lr=0.000100
# Iter=1372288/epoch=21, Loss=1.244464, Training Accuracy=0.593750, Top-5 Accuracy=0.921875, lr=0.000100
# Iter=1382528/epoch=21, Loss=1.136949, Training Accuracy=0.710938, Top-5 Accuracy=0.898438, lr=0.000100
# Iter=1392768/epoch=21, Loss=1.196958, Training Accuracy=0.687500, Top-5 Accuracy=0.906250, lr=0.000100
# Iter=1403008/epoch=22, Loss=1.287285, Training Accuracy=0.593750, Top-5 Accuracy=0.906250, lr=0.000100
# Iter=1413248/epoch=22, Loss=1.343437, Training Accuracy=0.609375, Top-5 Accuracy=0.882812, lr=0.000100
# Iter=1423488/epoch=22, Loss=1.212960, Training Accuracy=0.640625, Top-5 Accuracy=0.906250, lr=0.000100
# Iter=1433728/epoch=22, Loss=1.332724, Training Accuracy=0.593750, Top-5 Accuracy=0.914062, lr=0.000100
# Iter=1443968/epoch=22, Loss=1.299075, Training Accuracy=0.656250, Top-5 Accuracy=0.890625, lr=0.000100
# Iter=1454208/epoch=22, Loss=1.211928, Training Accuracy=0.656250, Top-5 Accuracy=0.890625, lr=0.000100
# Iter=1464448/epoch=23, Loss=1.118707, Training Accuracy=0.679688, Top-5 Accuracy=0.921875, lr=0.000100
# Iter=1474688/epoch=23, Loss=1.346838, Training Accuracy=0.617188, Top-5 Accuracy=0.882812, lr=0.000100
# Iter=1484928/epoch=23, Loss=1.161880, Training Accuracy=0.625000, Top-5 Accuracy=0.937500, lr=0.000100
# Iter=1495168/epoch=23, Loss=1.207633, Training Accuracy=0.570312, Top-5 Accuracy=0.921875, lr=0.000100
# Iter=1505408/epoch=23, Loss=1.229752, Training Accuracy=0.617188, Top-5 Accuracy=0.898438, lr=0.000100
# Iter=1515648/epoch=23, Loss=1.068185, Training Accuracy=0.687500, Top-5 Accuracy=0.937500, lr=0.000100
# Iter=1525888/epoch=24, Loss=1.142972, Training Accuracy=0.648438, Top-5 Accuracy=0.906250, lr=0.000100
# Iter=1536128/epoch=24, Loss=0.931944, Training Accuracy=0.718750, Top-5 Accuracy=0.960938, lr=0.000100
# Iter=1546368/epoch=24, Loss=1.116916, Training Accuracy=0.664062, Top-5 Accuracy=0.929688, lr=0.000100
# Iter=1556608/epoch=24, Loss=1.210001, Training Accuracy=0.617188, Top-5 Accuracy=0.921875, lr=0.000100
# Iter=1566848/epoch=24, Loss=1.112436, Training Accuracy=0.726562, Top-5 Accuracy=0.921875, lr=0.000100
# Iter=1577088/epoch=24, Loss=1.069646, Training Accuracy=0.687500, Top-5 Accuracy=0.937500, lr=0.000100
# Iter=1587328/epoch=25, Loss=1.020354, Training Accuracy=0.718750, Top-5 Accuracy=0.929688, lr=0.000100
# Iter=1597568/epoch=25, Loss=1.177829, Training Accuracy=0.601562, Top-5 Accuracy=0.937500, lr=0.000100
# Iter=1607808/epoch=25, Loss=1.061310, Training Accuracy=0.664062, Top-5 Accuracy=0.929688, lr=0.000100
# Iter=1618048/epoch=25, Loss=1.171037, Training Accuracy=0.632812, Top-5 Accuracy=0.937500, lr=0.000100
# Iter=1628288/epoch=25, Loss=1.081150, Training Accuracy=0.687500, Top-5 Accuracy=0.898438, lr=0.000100
# Iter=1638528/epoch=25, Loss=0.905236, Training Accuracy=0.726562, Top-5 Accuracy=0.937500, lr=0.000100
# Iter=1648768/epoch=26, Loss=0.782045, Training Accuracy=0.773438, Top-5 Accuracy=0.968750, lr=0.000100
# Iter=1659008/epoch=26, Loss=0.895838, Training Accuracy=0.734375, Top-5 Accuracy=0.960938, lr=0.000100
# Iter=1669248/epoch=26, Loss=1.286325, Training Accuracy=0.601562, Top-5 Accuracy=0.906250, lr=0.000100
# Iter=1679488/epoch=26, Loss=0.872477, Training Accuracy=0.726562, Top-5 Accuracy=0.960938, lr=0.000100
# Iter=1689728/epoch=26, Loss=0.866252, Training Accuracy=0.734375, Top-5 Accuracy=0.968750, lr=0.000100
# Iter=1699968/epoch=26, Loss=0.880823, Training Accuracy=0.703125, Top-5 Accuracy=0.945312, lr=0.000100
# Iter=1710208/epoch=27, Loss=0.953320, Training Accuracy=0.710938, Top-5 Accuracy=0.960938, lr=0.000100
# Iter=1720448/epoch=27, Loss=0.992473, Training Accuracy=0.671875, Top-5 Accuracy=0.945312, lr=0.000100
# Iter=1730688/epoch=27, Loss=0.933463, Training Accuracy=0.773438, Top-5 Accuracy=0.953125, lr=0.000100
# Iter=1740928/epoch=27, Loss=0.908464, Training Accuracy=0.703125, Top-5 Accuracy=0.960938, lr=0.000100
# Iter=1751168/epoch=27, Loss=0.955522, Training Accuracy=0.703125, Top-5 Accuracy=0.945312, lr=0.000100
# Iter=1761408/epoch=27, Loss=1.095836, Training Accuracy=0.656250, Top-5 Accuracy=0.929688, lr=0.000100
# Iter=1771648/epoch=27, Loss=0.795537, Training Accuracy=0.757812, Top-5 Accuracy=0.960938, lr=0.000100

# %%
exit()
